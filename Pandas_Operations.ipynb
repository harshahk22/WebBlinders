# %%
import pandas as pd

# %%
df = pd.read_csv("Fraud Detection Dataset.csv")

# %%
df
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# ...

# %%
df.head()
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# 4                 19.0      Mobile  San Francisco
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# ...

# %%
df.tail()
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 50995                 15.0      Mobile       New York
# 50996                  3.0      Mobile          Miami
# 50997                 18.0      Mobile  San Francisco
# 50998                 19.0      Tablet       New York
# 50999                  3.0      Tablet    Los Angeles
#
#        Previous_Fraudulent_Transactions  Account_Age  \
# 50995                                 0            7
# 50996                                 1           75
# 50997                                 3           73
# ...

# %%
df.describe()
# Out:
#             User_ID  Transaction_Amount  Time_of_Transaction  \
# count  51000.000000        48480.000000         48448.000000
# mean    3005.110176         2996.249784            11.488400
# std     1153.121107         5043.932555             6.922954
# min     1000.000000            5.030000             0.000000
# 25%     2007.000000         1270.552500             5.000000
# 50%     2996.000000         2524.100000            12.000000
# 75%     4006.000000         3787.240000            17.000000
# max     4999.000000        49997.800000            23.000000
#
#        Previous_Fraudulent_Transactions   Account_Age  \
# count                      51000.000000  51000.000000
# mean                           1.995725     60.033902
# std                            1.415150     34.384131
# min                            0.000000      1.000000
# 25%                            1.000000     30.000000
# 50%                            2.000000     60.000000
# ...

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'User_ID', 'Transaction_Amount', 'Transaction_Type',
#        'Time_of_Transaction', 'Device_Used', 'Location',
#        'Previous_Fraudulent_Transactions', 'Account_Age',
#        'Number_of_Transactions_Last_24H', 'Payment_Method', 'Fraudulent'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Transaction_ID                       object
# User_ID                               int64
# Transaction_Amount                  float64
# Transaction_Type                     object
# Time_of_Transaction                 float64
# Device_Used                          object
# Location                             object
# Previous_Fraudulent_Transactions      int64
# Account_Age                           int64
# Number_of_Transactions_Last_24H       int64
# Payment_Method                       object
# Fraudulent                            int64
# dtype: object

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Transaction_ID      object
# Transaction_Type    object
# Device_Used         object
# Location            object
# Payment_Method      object
# dtype: object

# %%
df1 = df[df.dtypes[df.dtypes == 'object'].index]

# %%
df1.describe()
# Out:
#        Transaction_ID Transaction_Type Device_Used Location Payment_Method
# count           51000            51000       48527    48453          48531
# unique          50000                5           4        8              5
# top            T48225     Bill Payment     Desktop   Boston            UPI
# freq                2            10340       15795     6149          11887

# %%
df.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                         2473
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %%
df2 = df["Location"]

# %%
type(df2)
# Out:
# pandas.core.series.Series

# %%
df2 = df[["Location"]]

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["User_ID","Transaction_Amount"]][1:20]
# Out:
#     User_ID  Transaction_Amount
# 1      4507             1554.58
# 2      1860             2395.02
# 3      2294              100.10
# 4      2130             1490.50
# 5      2095             2372.04
# 6      4772              544.81
# 7      4092              635.75
# 8      2638             2318.87
# 9      3169             3656.17
# 10     1466                 NaN
# 11     2238             2733.84
# 12     1330             2376.37
# 13     2482             1924.48
# 14     3135              968.78
# 15     4444              737.08
# 16     4171             3960.52
# 17     3919             2327.71
# 18     4735             3952.65
# 19     1130             3521.89

# %%
df.iloc[0:4]
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
#
#    Number_of_Transactions_Last_24H Payment_Method  Fraudulent
# 0                               13     Debit Card           0
# ...

# %%
df[df["Device_Used"] == "Desktop"]
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 3                 T4     2294              100.10     Bill Payment
# 5                 T6     2095             2372.04   ATM Withdrawal
# 30               T31     3324              428.39      POS Payment
# 32               T33     1459             2212.25  Online Purchase
# 36               T37     1747             4699.58      POS Payment
# ...              ...      ...                 ...              ...
# 50987         T33986     2365             4232.39   ATM Withdrawal
# 50988         T11626     4614             1909.03    Bank Transfer
# 50989         T12137     1617             2278.46    Bank Transfer
# 50990         T12629     1157             2898.06  Online Purchase
# 50992         T43512     1584             3631.26    Bank Transfer
#
#        Time_of_Transaction Device_Used       Location  \
# 3                     15.0     Desktop        Chicago
# ...

# %%
df[df["Transaction_Amount"]>49000]
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 166             T167     1502             49997.8      POS Payment
# 236             T237     2529             49997.8   ATM Withdrawal
# 245             T246     2306             49997.8     Bill Payment
# 298             T299     2153             49997.8  Online Purchase
# 317             T318     4681             49997.8     Bill Payment
# ...              ...      ...                 ...              ...
# 50570          T4789     2627             49997.8  Online Purchase
# 50597         T13479     4753             49997.8     Bill Payment
# 50705         T35840     2194             49997.8   ATM Withdrawal
# 50863          T6916     1636             49997.8  Online Purchase
# 50945         T11505     4969             49997.8   ATM Withdrawal
#
#        Time_of_Transaction Device_Used       Location  \
# 166                    3.0     Desktop          Miami
# ...

# %%
df["new"] = df["Previous_Fraudulent_Transactions"]+df["Number_of_Transactions_Last_24H"]
df
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# ...

# %%
df.dtypes
# Out:
# Transaction_ID                       object
# User_ID                               int64
# Transaction_Amount                  float64
# Transaction_Type                     object
# Time_of_Transaction                 float64
# Device_Used                          object
# Location                             object
# Previous_Fraudulent_Transactions      int64
# Account_Age                           int64
# Number_of_Transactions_Last_24H       int64
# Payment_Method                       object
# Fraudulent                            int64
# new                                   int64
# dtype: object

# %%
df.drop("new",axis=1,inplace=True)

# %%
df
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# ...

# %%
df.shape
# Out:
# (51000, 12)

# %%
df = df.rename(columns={"Transaction_ID":"ID"})

# %%
df.columns
# Out:
# Index(['ID', 'User_ID', 'Transaction_Amount', 'Transaction_Type',
#        'Time_of_Transaction', 'Device_Used', 'Location',
#        'Previous_Fraudulent_Transactions', 'Account_Age',
#        'Number_of_Transactions_Last_24H', 'Payment_Method', 'Fraudulent'],
#       dtype='object')
